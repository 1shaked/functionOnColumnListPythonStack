# %%
import pandas as pd

df = pd.read_csv('Top 50 Youtube Channels.csv')



def func(cols):
    return cols

cols = ['Rank', 'Channel name']
df.loc[:, cols] = df.loc[:, cols].apply(func)

# %%
df[['Channel name', 'Network']]
# Out:
#                                          Channel name  \
# 0                                            T-Series
# 1                          Cocomelon - Nursery Rhymes
# 2                                           SET India
# 3                                            Sony SAB
# 4                                         Like Nastya
# 5                                     Kids Diana Show
# 6                                                 WWE
# 7                                       Vlad and Niki
# 8                                          Movieclips
# 9                                           Colors TV
# 10                                       Ryan's World
# 11                                         netd müzik
# 12                                  El Reino Infantil
# 13                                  Zee Music Company
# 14                              ABS-CBN Entertainment
# 15                                    Toys and Colors
# 16              ChuChu TV Nursery Rhymes & Kids Songs
# 17                    Super Simple Songs - Kids Songs
# 18                                         Wave Music
# 19      Little Baby Bum - Nursery Rhymes & Kids Songs
# 20                                          KondZilla
# 21        Pinkfong Baby Shark - Kids' Songs & Stories
# 22                                  WorkpointOfficial
# 23                                     Маша и Медведь
# 24                                     ARY Digital HD
# 25                                                YRF
# 26                                        Har Pal Geo
# 27  LooLoo Kids - Nursery Rhymes and Children's Songs
# 28                                      Tips Official
# 29                                             Zee TV
# 30                               Shemaroo Filmi Gaane
# 31                                      Justin Bieber
# 32                                           LankyBox
# 33                                         Get Movies
# 34                                          PewDiePie
# 35                                         Ed Sheeran
# 36                                          BLACKPINK
# 37                                        GMA Network
# 38                                       Taylor Swift
# 39                                          Bad Bunny
# 40                                  Infobells - Hindi
# 41                                             One 31
# 42                                   Sony Music India
# 43                   قناة طيور الجنة | toyoraljanahtv
# 44                              T-Series Bhakti Sagar
# 45                                         D Billions
# 46                                    DisneyMusicVevo
# 47                                             SMTOWN
# 48                                        HYBE LABELS
# 49                                   JustinBieberVEVO
#
#                            Network
# 0                         T-Series
# 1            Moonbug Entertainment
# 2         Culver Max Entertainment
# 3         Culver Max Entertainment
# 4                            Yoola
# 5                              AIR
# 6                              WWE
# 7                                —
# 8       Rotten Tomatoes Movieclips
# 9                         Viacom18
# 10                     PocketWatch
# 11                        netd.com
# 12                    Leader Music
# 13   Zee Entertainment Enterprises
# 14                         ABS-CBN
# 15                               —
# 16                       ChuChu TV
# 17                               —
# 18                             NaN
# 19                               —
# 20                          ONErpm
# 21            The Pinkfong Company
# 22         Workpoint Entertainment
# 23                      LetsonCorp
# 24             ARY Digital Network
# 25                             YRF
# 26               Geo Entertainment
# 27                               —
# 28                 Tips Industries
# 29   Zee Entertainment Enterprises
# 30                  Shemaroo Music
# 31                               —
# 32                             NaN
# 33                      LetsonCorp
# 34                            re6l
# 35                               —
# 36                YG Entertainment
# 37                     GMA Network
# 38                               —
# 39                               —
# 40  Infobelle Interactive Solution
# 41                      GMM Grammy
# 42        Culver Max Entertainment
# 43                               —
# 44                               —
# 45                             NaN
# 46         The Walt Disney Company
# 47                SM Entertainment
# 48                Hybe Corporation
# 49                            Vevo

# %%
import pandas as pd

df = pd.read_csv('Top 50 Youtube Channels.csv')



def func(col: pd.Series):
    '''
    here you get a Series of all the elements as a 
    '''
    col = col.apply(lambda v: str(v).split(' ')[0])
    return col

cols = ['Network', 'Channel name']
df.loc[:, cols] = df.loc[:, cols].apply(func)

# %%
df[['Channel name', 'Network']]
# Out:
#                                          Channel name  \
# 0                                            T-Series
# 1                          Cocomelon - Nursery Rhymes
# 2                                           SET India
# 3                                            Sony SAB
# 4                                         Like Nastya
# 5                                     Kids Diana Show
# 6                                                 WWE
# 7                                       Vlad and Niki
# 8                                          Movieclips
# 9                                           Colors TV
# 10                                       Ryan's World
# 11                                         netd müzik
# 12                                  El Reino Infantil
# 13                                  Zee Music Company
# 14                              ABS-CBN Entertainment
# 15                                    Toys and Colors
# 16              ChuChu TV Nursery Rhymes & Kids Songs
# 17                    Super Simple Songs - Kids Songs
# 18                                         Wave Music
# 19      Little Baby Bum - Nursery Rhymes & Kids Songs
# 20                                          KondZilla
# 21        Pinkfong Baby Shark - Kids' Songs & Stories
# 22                                  WorkpointOfficial
# 23                                     Маша и Медведь
# 24                                     ARY Digital HD
# 25                                                YRF
# 26                                        Har Pal Geo
# 27  LooLoo Kids - Nursery Rhymes and Children's Songs
# 28                                      Tips Official
# 29                                             Zee TV
# 30                               Shemaroo Filmi Gaane
# 31                                      Justin Bieber
# 32                                           LankyBox
# 33                                         Get Movies
# 34                                          PewDiePie
# 35                                         Ed Sheeran
# 36                                          BLACKPINK
# 37                                        GMA Network
# 38                                       Taylor Swift
# 39                                          Bad Bunny
# 40                                  Infobells - Hindi
# 41                                             One 31
# 42                                   Sony Music India
# 43                   قناة طيور الجنة | toyoraljanahtv
# 44                              T-Series Bhakti Sagar
# 45                                         D Billions
# 46                                    DisneyMusicVevo
# 47                                             SMTOWN
# 48                                        HYBE LABELS
# 49                                   JustinBieberVEVO
#
#                            Network
# 0                         T-Series
# 1            Moonbug Entertainment
# 2         Culver Max Entertainment
# 3         Culver Max Entertainment
# 4                            Yoola
# 5                              AIR
# 6                              WWE
# 7                                —
# 8       Rotten Tomatoes Movieclips
# 9                         Viacom18
# 10                     PocketWatch
# 11                        netd.com
# 12                    Leader Music
# 13   Zee Entertainment Enterprises
# 14                         ABS-CBN
# 15                               —
# 16                       ChuChu TV
# 17                               —
# 18                             NaN
# 19                               —
# 20                          ONErpm
# 21            The Pinkfong Company
# 22         Workpoint Entertainment
# 23                      LetsonCorp
# 24             ARY Digital Network
# 25                             YRF
# 26               Geo Entertainment
# 27                               —
# 28                 Tips Industries
# 29   Zee Entertainment Enterprises
# 30                  Shemaroo Music
# 31                               —
# 32                             NaN
# 33                      LetsonCorp
# 34                            re6l
# 35                               —
# 36                YG Entertainment
# 37                     GMA Network
# 38                               —
# 39                               —
# 40  Infobelle Interactive Solution
# 41                      GMM Grammy
# 42        Culver Max Entertainment
# 43                               —
# 44                               —
# 45                             NaN
# 46         The Walt Disney Company
# 47                SM Entertainment
# 48                Hybe Corporation
# 49                            Vevo
